# %%
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.6.15)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4fbd93d4-48ef-4945-ad03-9090ac240668" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4fbd93d4-48ef-4945-ad03-9090ac240668">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"vaibhav2006","key":"7260a46753f2929423a2d8fba003fa26"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d gspmoreira/articles-sharing-reading-from-cit-deskdrop
# Out:
# Downloading articles-sharing-reading-from-cit-deskdrop.zip to /content
#  61% 5.00M/8.20M [00:00<00:00, 30.5MB/s]
# 100% 8.20M/8.20M [00:00<00:00, 47.2MB/s]

# %%
# !unzip articles-sharing-reading-from-cit-deskdrop.zip
# Out:
# Archive:  articles-sharing-reading-from-cit-deskdrop.zip
#   inflating: shared_articles.csv
#   inflating: users_interactions.csv

# %%
import pandas as pd
import numpy as np

df_shared_articles = pd.read_csv("shared_articles.csv")
df_users_interactions = pd.read_csv("users_interactions.csv")

# %%
df_users_interactions.head()
# Out:
#     timestamp eventType            contentId             personId  \
# 0  1465413032      VIEW -3499919498720038879 -8845298781299428018
# 1  1465412560      VIEW  8890720798209849691 -1032019229384696495
# 2  1465416190      VIEW   310515487419366995 -1130272294246983140
# 3  1465413895    FOLLOW   310515487419366995   344280948527967603
# 4  1465412290      VIEW -7820640624231356730  -445337111692715325
#
#              sessionId                                          userAgent  \
# 0  1264196770339959068                                                NaN
# 1  3621737643587579081  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2...
# 2  2631864456530402479                                                NaN
# 3 -3167637573980064150                                                NaN
# 4  5611481178424124714                                                NaN
#
#   userRegion userCountry
# 0        NaN         NaN
# 1         NY          US
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %%
df_shared_articles = df_shared_articles[df_shared_articles['eventType'] == "CONTENT SHARED"]

print(len(df_shared_articles))
df_shared_articles.head()
# Out:
# 3047
#     timestamp       eventType            contentId       authorPersonId  \
# 1  1459193988  CONTENT SHARED -4110354420726924665  4340306774493623681
# 2  1459194146  CONTENT SHARED -7292285110016212249  4340306774493623681
# 3  1459194474  CONTENT SHARED -6151852268067518688  3891637997717104548
# 4  1459194497  CONTENT SHARED  2448026894306402386  4340306774493623681
# 5  1459194522  CONTENT SHARED -2826566343807132236  4340306774493623681
#
#        authorSessionId authorUserAgent authorRegion authorCountry contentType  \
# 1  8940341205206233829             NaN          NaN           NaN        HTML
# 2  8940341205206233829             NaN          NaN           NaN        HTML
# 3 -1457532940883382585             NaN          NaN           NaN        HTML
# 4  8940341205206233829             NaN          NaN           NaN        HTML
# 5  8940341205206233829             NaN          NaN           NaN        HTML
#
#                                                  url  \
# 1  http://www.nytimes.com/2016/03/28/business/dea...
# 2  http://cointelegraph.com/news/bitcoin-future-w...
# 3  https://cloudplatform.googleblog.com/2016/03/G...
# 4  https://bitcoinmagazine.com/articles/ibm-wants...
# 5  http://www.coindesk.com/ieee-blockchain-oxford...
#
#                                                title  \
# 1  Ethereum, a Virtual Currency, Enables Transact...
# 2  Bitcoin Future: When GBPcoin of Branson Wins O...
# 3                       Google Data Center 360° Tour
# 4  IBM Wants to "Evolve the Internet" With Blockc...
# 5  IEEE to Talk Blockchain at Cloud Computing Oxf...
#
#                                                 text lang
# 1  All of this work is still very early. The firs...   en
# 2  The alarm clock wakes me at 8:00 with stream o...   en
# 3  We're excited to share the Google Data Center ...   en
# 4  The Aite Group projects the blockchain market ...   en
# 5  One of the largest and oldest organizations fo...   en

# %%
def findTotalEvents(x):
  total_likes = df_users_interactions[(df_users_interactions["contentId"] == x["contentId"]) & (df_users_interactions["eventType"] == "LIKE")].shape[0]
  total_views = df_users_interactions[(df_users_interactions["contentId"] == x["contentId"]) & (df_users_interactions["eventType"] == "VIEW")].shape[0]
  total_bookmarks = df_users_interactions[(df_users_interactions["contentId"] == x["contentId"]) & (df_users_interactions["eventType"] == "BOOKMARK")].shape[0]
  total_follows = df_users_interactions[(df_users_interactions["contentId"] == x["contentId"]) & (df_users_interactions["eventType"] == "FOLLOW")].shape[0]
  total_comment_created = df_users_interactions[(df_users_interactions["contentId"] == x["contentId"]) & (df_users_interactions["eventType"] == "COMMENT CREATED")].shape[0]
  return total_likes + total_views + total_bookmarks + total_follows + total_comment_created

df_shared_articles["total_events"] = df_shared_articles.apply(findTotalEvents, axis=1)

# %%
df_shared_articles = df_shared_articles.sort_values('total_events', ascending = False)
df_shared_articles[['timestamp', 'authorSessionId', 'contentType', 'url', 'title' , 'text', 'lang' ,'total_events']].head(10)
# Out:
#        timestamp      authorSessionId contentType  \
# 3096  1487246811 -6569695881431984742        HTML
# 1671  1467813728 -5701227433817087697        HTML
# 1814  1468867647 -8995217520473210153        HTML
# 1317  1465484901   838596071610016700        HTML
# 588   1461629452 -1297230017812472163        HTML
# 2308  1473593226  5016857076790212194        HTML
# 1902  1469678235  2045534933671019150        HTML
# 1942  1469992520   611377856408166257        HTML
# 1724  1468247818 -9077035980881675856        HTML
# 2095  1471520397  1000828687449358272        HTML
#
#                                                     url  \
# 3096  http://www.cnbc.com/2016/12/21/former-google-c...
# 1671  http://gq.globo.com/Prazeres/Poder/Carreira/no...
# 1814  http://www.caroli.org/livro-retrospectivas-div...
# 1317  https://medium.com/practical-blend/pull-reques...
# 588   https://medium.com/@jeffersoncn/ganhe-6-meses-...
# 2308  http://www.attps.com.br/cinco-motivos-para-inv...
# 1902  http://www.geekwire.com/2016/ray-kurzweil-worl...
# 1942  https://medium.com/@rdsubhas/10-modern-softwar...
# 1724  https://viagensdealline.com/2013/08/20/a-minha...
# 2095  https://medium.com/@roxrogge/ux-ou-ui-4c0a1bcb...
#
#                                                   title  \
# 3096  Former Google career coach shares a visual tri...
# 1671  Novo workaholic trabalha, pratica esportes e t...
# 1814                   Livro: Retrospectivas Divertidas
# 1317               Pull request first - Practical Blend
# 588   Ganhe 6 meses de acesso ao Pluralsight, maior ...
# 2308  Custo do Erro - Cinco motivos para investir em...
# 1902  Ray Kurzweil: The world isn't getting worse - ...
# 1942       10 Modern Software Over-Engineering Mistakes
# 1724          A minha viagem à Maternidade #tetodomundo
# 2095                                          UX ou UI?
#
#                                                    text lang  total_events
# 3096  If you want 2017 to be an exciting year, desig...   en           433
# 1671  Novo workaholic não abre mão do esporte e da f...   pt           315
# 1814  Neste livro, nós fornecemos um conjunto de fer...   pt           294
# 1317  Pull request first After two years of working ...   en           294
# 588   Ganhe 6 meses de acesso ao Pluralsight, maior ...   pt           281
# 2308  Atualmente, o custo de manutenção de software ...   pt           280
# 1902  Ray Kurzweil, the author, inventor, computer s...   en           266
# 1942  10 Modern Software Over-Engineering Mistakes F...   en           255
# 1724  Já fazia uma semana, desde o dia 26 de dezembr...   pt           253
# 2095  UX ou UI? Tenho escutado essa pergunta com fre...   pt           249

# %%
def converting_to_lowerCase(x):
  if isinstance(x, str):
    return str.lower(x.replace(" ", ""))
  else:
    return " "

df_shared_articles["title"] = df_shared_articles["title"].apply(converting_to_lowerCase)

df_shared_articles[['timestamp', 'authorSessionId', 'contentType', 'url', 'title' , 'text', 'lang' ,'total_events']]
# Out:
#        timestamp      authorSessionId contentType  \
# 3096  1487246811 -6569695881431984742        HTML
# 1671  1467813728 -5701227433817087697        HTML
# 1814  1468867647 -8995217520473210153        HTML
# 1317  1465484901   838596071610016700        HTML
# 588   1461629452 -1297230017812472163        HTML
# ...          ...                  ...         ...
# 115   1459423691  3903381901308718595        HTML
# 788   1462388809  -644438690559295938        HTML
# 1083  1464088373  1383007417300661586        HTML
# 1572  1467163080  7326684951184565497        HTML
# 781   1462370266 -2574177513386348910        HTML
#
#                                                     url  \
# 3096  http://www.cnbc.com/2016/12/21/former-google-c...
# 1671  http://gq.globo.com/Prazeres/Poder/Carreira/no...
# 1814  http://www.caroli.org/livro-retrospectivas-div...
# 1317  https://medium.com/practical-blend/pull-reques...
# 588   https://medium.com/@jeffersoncn/ganhe-6-meses-...
# ...                                                 ...
# 115   http://bitcoinist.net/cashila-announces-conven...
# 788                http://www.imdb.com/title/tt1276419/
# 1083  http://algorithmicassertions.com/2016/05/22/qu...
# 1572  http://www.mckinsey.com/industries/high-tech/o...
# 781   http://www.wired.com/2016/05/ibm-letting-anyon...
#
#                                                   title  \
# 3096  formergooglecareercoachsharesavisualtrickforfi...
# 1671  novoworkaholictrabalha,praticaesportesetemtemp...
# 1814                     livro:retrospectivasdivertidas
# 1317                    pullrequestfirst-practicalblend
# 588   ganhe6mesesdeacessoaopluralsight,maiorplatafor...
# ...                                                 ...
# 115   cashilaannouncesconvenientbuyandsellfeaturefor...
# 788                                  aroyalaffair(2012)
# 1083                    myquantumcircuitsimulator:quirk
# 1572  usinganalyticstoturbochargechina'se-commercepe...
# 781     ibmisnowlettinganyoneplaywithitsquantumcomputer
#
#                                                    text lang  total_events
# 3096  If you want 2017 to be an exciting year, desig...   en           433
# 1671  Novo workaholic não abre mão do esporte e da f...   pt           315
# 1814  Neste livro, nós fornecemos um conjunto de fer...   pt           294
# 1317  Pull request first After two years of working ...   en           294
# 588   Ganhe 6 meses de acesso ao Pluralsight, maior ...   pt           281
# ...                                                 ...  ...           ...
# 115   There seems to be no love lost between central...   en             0
# 788   Nominated for 1 Oscar. Another 21 wins & 35 no...   en             0
# 1083  MathJax was blocked. Formulas like $\frac{a}{b...   en             0
# 1572  Facing market saturation and more selective co...   en             0
# 781   Quantum computing is computing at its most eso...   en             0
#
# [3047 rows x 8 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

count = CountVectorizer(stop_words = "english")
data_matrix = count.fit_transform(df_shared_articles["title"])

cosine_simil = cosine_similarity(data_matrix, data_matrix)

df_movies = df_shared_articles.reset_index()
indices = pd.Series(df_shared_articles.index, index = df_shared_articles['title'])

# %%
def Recomendations(title, cosine_sim):
  index = indices[title]
  
  total_events = list(enumerate(cosine_sim[index]))
  total_events = sorted(total_events, key = lambda x:x[1], reverse = True)
  total_events = total_events[1:11]

  articles_index = [i[0] for i in total_events]
  return df_shared_articles['title'].iloc[articles_index]

# %%
Recomendations("pullrequestfirst-practicalblend", cosine_simil)
# Out:
# 901      consórcio:vendadenovascotascai13,5%no1ºtrimestre
# 3096    formergooglecareercoachsharesavisualtrickforfi...
# 1671    novoworkaholictrabalha,praticaesportesetemtemp...
# 1814                       livro:retrospectivasdivertidas
# 1317                      pullrequestfirst-practicalblend
# 588     ganhe6mesesdeacessoaopluralsight,maiorplatafor...
# 2308    custodoerro-cincomotivosparainvestiremautomaçã...
# 1902    raykurzweil:theworldisn'tgettingworse-ourinfor...
# 1942             10modernsoftwareover-engineeringmistakes
# 1724                 aminhaviagemàmaternidade#tetodomundo
# Name: title, dtype: object
